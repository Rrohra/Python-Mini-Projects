# %%
cd pycharm workspace
# Out:
# [WinError 2] The system cannot find the file specified: 'pycharm workspace'
# D:\pycharm workspace

# %%
import pandas
a=pandas.read_json("095 supermarkets.json")

# %%
a=a.set_index("ID")

# %%
a
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
a.loc["1":"4", "Address":"Country"]
# Out:
#            Address           City Country
# ID
# 1     3666 21st St  San Francisco     USA
# 2   735 Dolores St  San Francisco     USA
# 3      332 Hill St  San Francisco     USA
# 4     3995 23rd St  San Francisco     USA

# %%
a.iloc[1:4,1:5]
# Out:
#              City Country  Employees         Name
# ID
# 2   San Francisco     USA         15  Bready Shop
# 3   San Francisco     USA         25  Super River
# 4   San Francisco     USA         10   Ben's Shop

# %%
a.ix[1,3]
# Out:
# d:\python extracted files\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 8

# %%
a.drop("City",1)
# Out:
#             Address Country  Employees         Name             State
# ID
# 1      3666 21st St     USA          8      Madeira          CA 94114
# 2    735 Dolores St     USA         15  Bready Shop          CA 94119
# 3       332 Hill St     USA         25  Super River  California 94114
# 4      3995 23rd St     USA         10   Ben's Shop          CA 94114
# 5   1056 Sanchez St     USA         12      Sanchez        California
# 6   551 Alvarado St     USA         20   Richvalley          CA 94114

# %%
a.drop(2,0)
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
a=a.set_index("Address")

# %%
a
# Out:
#                           City Country  Employees         Name  \
# Address
# 3666 21st St     San Francisco     USA          8      Madeira
# 735 Dolores St   San Francisco     USA         15  Bready Shop
# 332 Hill St      San Francisco     USA         25  Super River
# 3995 23rd St     San Francisco     USA         10   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12      Sanchez
# 551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
a.drop("1056 Sanchez St", 0)
# Out:
#                           City Country  Employees         Name  \
# Address
# 3666 21st St     San Francisco     USA          8      Madeira
# 735 Dolores St   San Francisco     USA         15  Bready Shop
# 332 Hill St      San Francisco     USA         25  Super River
# 3995 23rd St     San Francisco     USA         10   Ben's Shop
# 551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 551 Alvarado St          CA 94114

# %%
a
# Out:
#                           City Country  Employees         Name  \
# Address
# 3666 21st St     San Francisco     USA          8      Madeira
# 735 Dolores St   San Francisco     USA         15  Bready Shop
# 332 Hill St      San Francisco     USA         25  Super River
# 3995 23rd St     San Francisco     USA         10   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12      Sanchez
# 551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
a=a.set_index("Country")

# %%
a
# Out:
#                   City  Employees         Name             State
# Country
# USA      San Francisco          8      Madeira          CA 94114
# USA      San Francisco         15  Bready Shop          CA 94119
# USA      San Francisco         25  Super River  California 94114
# USA      San Francisco         10   Ben's Shop          CA 94114
# USA      San Francisco         12      Sanchez        California
# USA      San Francisco         20   Richvalley          CA 94114

# %%
a.drop("USA", 0)
# Out:
# Empty DataFrame
# Columns: [City, Employees, Name, State]
# Index: []

# %%
a
# Out:
#                   City  Employees         Name             State
# Country
# USA      San Francisco          8      Madeira          CA 94114
# USA      San Francisco         15  Bready Shop          CA 94119
# USA      San Francisco         25  Super River  California 94114
# USA      San Francisco         10   Ben's Shop          CA 94114
# USA      San Francisco         12      Sanchez        California
# USA      San Francisco         20   Richvalley          CA 94114

# %%
a.shape[1]
# Out:
# 4

# %%
a=a.set_index("ID")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\python extracted files\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-24e3abd14eaa> in <module>
# ----> 1 a=a.set_index("ID")
#
# ...

# %%
a=pandas.read_json("095 supermarkets.json")

# %%
a
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
a["RELIGION"] = a.shape[0]*["humanity"]

# %%
a
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State  RELIGION
# 0          CA 94114  humanity
# 1          CA 94119  humanity
# 2  California 94114  humanity
# 3          CA 94114  humanity
# 4        California  humanity
# 5          CA 94114  humanity

# %%
a["RELIGION"]=pandas._get_loc(0)* ["hindu"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-1674827a883d> in <module>
# ----> 1 a["RELIGION"]=pandas._get_loc(0)* ["hindu"]
#
# AttributeError: module 'pandas' has no attribute '_get_loc'

# %%
type(a.shape[0])
# Out:
# int

# %%
a_t=a.T

# %%
a_t
# Out:
#                        0               1                 2              3  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# Country              USA             USA               USA            USA
# Employees              8              15                25             10
# ID                     1               2                 3              4
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# State           CA 94114        CA 94119  California 94114       CA 94114
# RELIGION        humanity        humanity          humanity       humanity
#
#                          4                5
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# Country                USA              USA
# Employees               12               20
# ID                       5                6
# ...

# %%
a_t[6]= ["a","b","c",4,5,"d", "r","z"]
a_t
# Out:
#                        0               1                 2              3  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# Country              USA             USA               USA            USA
# Employees              8              15                25             10
# ID                     1               2                 3              4
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# State           CA 94114        CA 94119  California 94114       CA 94114
# RELIGION        humanity        humanity          humanity       humanity
#
#                          4                5  6
# Address    1056 Sanchez St  551 Alvarado St  a
# City         San Francisco    San Francisco  b
# Country                USA              USA  c
# Employees               12               20  4
# ID                       5                6  5
# ...

# %%
a=a_t.T

# %%
a
# Out:
#            Address           City Country Employees ID         Name  \
# 0     3666 21st St  San Francisco     USA         8  1      Madeira
# 1   735 Dolores St  San Francisco     USA        15  2  Bready Shop
# 2      332 Hill St  San Francisco     USA        25  3  Super River
# 3     3995 23rd St  San Francisco     USA        10  4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA        12  5      Sanchez
# 5  551 Alvarado St  San Francisco     USA        20  6   Richvalley
# 6                a              b       c         4  5            d
#
#               State  RELIGION
# 0          CA 94114  humanity
# 1          CA 94119  humanity
# 2  California 94114  humanity
# 3          CA 94114  humanity
# 4        California  humanity
# 5          CA 94114  humanity
# 6                 r         z

# %%
a["Country"]=["","","","usa","<","",""]

# %%
a
# Out:
#            Address           City Country Employees ID         Name  \
# 0     3666 21st St  San Francisco                 8  1      Madeira
# 1   735 Dolores St  San Francisco                15  2  Bready Shop
# 2      332 Hill St  San Francisco                25  3  Super River
# 3     3995 23rd St  San Francisco     usa        10  4   Ben's Shop
# 4  1056 Sanchez St  San Francisco       <        12  5      Sanchez
# 5  551 Alvarado St  San Francisco                20  6   Richvalley
# 6                a              b                 4  5            d
#
#               State  RELIGION
# 0          CA 94114  humanity
# 1          CA 94119  humanity
# 2  California 94114  humanity
# 3          CA 94114  humanity
# 4        California  humanity
# 5          CA 94114  humanity
# 6                 r         z

# %%
a=a.set_index("Address")

# %%
a
# Out:
#                           City Country  Employees         Name  \
# Address
# 3666 21st St     San Francisco     USA          8      Madeira
# 735 Dolores St   San Francisco     USA         15  Bready Shop
# 332 Hill St      San Francisco     USA         25  Super River
# 3995 23rd St     San Francisco     USA         10   Ben's Shop
# 1056 Sanchez St  San Francisco     USA         12      Sanchez
# 551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                             State
# Address
# 3666 21st St             CA 94114
# 735 Dolores St           CA 94119
# 332 Hill St      California 94114
# 3995 23rd St             CA 94114
# 1056 Sanchez St        California
# 551 Alvarado St          CA 94114

# %%
a["RELIGION"] = a.shape[0]*["humanity"]

# %%
a=a.set_index("ID")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\python extracted files\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-24e3abd14eaa> in <module>
# ----> 1 a=a.set_index("ID")
#
# ...

# %%
a=pandas.read_json("095 supermarkets.json")
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d7a2b9637c3c> in <module>
# ----> 1 a=pandas.read_json("095 supermarkets.json")
#       2 a
#
# NameError: name 'pandas' is not defined

# %%
import pandas

# %%
a=pandas.read_json("095 supermarkets.json")
a
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
import geopy

# %%
from geopy.geocoders import Nominatim

# %%
nom= Nominatim(user_agent="first_notebook")

# %% [markdown]
# nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
b=nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
b
# Out:
# Location(3995, 23rd Street, Noe Valley, SF, California, 94114, USA, (37.7529648, -122.4317141, 0.0))

# %%
b.latitude
b.longitude
# Out:
# -122.4317141

# %%
import pandas
a=pandas.read_json("095 supermarkets.json")

a["Address"]=a["Address"]+ ","+a["City"]+ "," +a["State"]
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114

# %%
import geopy

# %%
a["longitude"]=a.shape[0]*a["Address"].apply(nom.geocode)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# d:\python extracted files\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# d:\python extracted files\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# d:\python extracted files\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
# ...

# %%
a["longitude"]=a["Address"].apply(nom.geocode)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# d:\python extracted files\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# d:\python extracted files\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# d:\python extracted files\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
# ...

# %%
a["longitude"]=a["Address"].apply(nom.geocode.longitude)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-732d640e5792> in <module>
# ----> 1 a["longitude"]=a["Address"].apply(nom.geocode.longitude)
#
# AttributeError: 'function' object has no attribute 'longitude'

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                            longitude
# 0  (3666, 21st Street, Noe Valley, SF, California...
# ...

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                            longitude
# 0  (3666, 21st Street, Noe Valley, SF, California...
# ...

# %%
a["coordinates"]= a["longitude"]

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                            longitude  \
# 0  (3666, 21st Street, Noe Valley, SF, California...
# ...

# %%
a.drop("longitude",1)
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates
# 0  (3666, 21st Street, Noe Valley, SF, California...
# ...

# %%
a["latitude"]= a["coordinates"].apply(lambda x: x.latitude)

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                            longitude  \
# 0  (3666, 21st Street, Noe Valley, SF, California...
# ...

# %%
cols = a.columns.tolist()

# %%
cols
# Out:
# ['Address',
#  'City',
#  'Country',
#  'Employees',
#  'ID',
#  'Name',
#  'State',
#  'longitude',
#  'coordinates',
#  'latitude']

# %%
cols = cols[-1:] + cols[:-1]

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                            longitude  \
# 0  (3666, 21st Street, Noe Valley, SF, California...
# ...

# %%
a[cols]
# Out:
#     latitude                                     Address           City  \
# 0  37.756489         3666 21st St,San Francisco,CA 94114  San Francisco
# 1  37.757726       735 Dolores St,San Francisco,CA 94119  San Francisco
# 2  37.755725  332 Hill St,San Francisco,California 94114  San Francisco
# 3  37.752965         3995 23rd St,San Francisco,CA 94114  San Francisco
# 4  37.752146    1056 Sanchez St,San Francisco,California  San Francisco
# 5  37.753673      551 Alvarado St,San Francisco,CA 94114  San Francisco
#
#   Country  Employees  ID         Name             State  \
# 0     USA          8   1      Madeira          CA 94114
# 1     USA         15   2  Bready Shop          CA 94119
# 2     USA         25   3  Super River  California 94114
# 3     USA         10   4   Ben's Shop          CA 94114
# 4     USA         12   5      Sanchez        California
# 5     USA         20   6   Richvalley          CA 94114
#
#                                            longitude  \
# ...

# %%
cols = cols[-2:] + cols[:-2]
a[cols]
# Out:
#                                            longitude  \
# 0  (3666, 21st Street, Noe Valley, SF, California...
# 1  (735, Dolores Street, Liberty Street Historic ...
# 2  (332, Hill Street, Noe Valley, SF, California,...
# 3  (3995, 23rd Street, Noe Valley, SF, California...
# 4  (1056, Sanchez Street, Noe Valley, SF, Califor...
# 5  (551, Alvarado Street, Noe Valley, SF, Califor...
#
#                                          coordinates   latitude  \
# 0  (3666, 21st Street, Noe Valley, SF, California...  37.756489
# 1  (735, Dolores Street, Liberty Street Historic ...  37.757726
# 2  (332, Hill Street, Noe Valley, SF, California,...  37.755725
# 3  (3995, 23rd Street, Noe Valley, SF, California...  37.752965
# 4  (1056, Sanchez Street, Noe Valley, SF, Califor...  37.752146
# 5  (551, Alvarado Street, Noe Valley, SF, Califor...  37.753673
#
#                                       Address           City Country  \
# ...

# %%
cols = cols[-3:] + cols[:-3]
a[cols]
# Out:
#    ID         Name             State  \
# 0   1      Madeira          CA 94114
# 1   2  Bready Shop          CA 94119
# 2   3  Super River  California 94114
# 3   4   Ben's Shop          CA 94114
# 4   5      Sanchez        California
# 5   6   Richvalley          CA 94114
#
#                                            longitude  \
# 0  (3666, 21st Street, Noe Valley, SF, California...
# 1  (735, Dolores Street, Liberty Street Historic ...
# 2  (332, Hill Street, Noe Valley, SF, California,...
# 3  (3995, 23rd Street, Noe Valley, SF, California...
# 4  (1056, Sanchez Street, Noe Valley, SF, Califor...
# 5  (551, Alvarado Street, Noe Valley, SF, Califor...
#
#                                          coordinates   latitude  \
# 0  (3666, 21st Street, Noe Valley, SF, California...  37.756489
# 1  (735, Dolores Street, Liberty Street Historic ...  37.757726
# 2  (332, Hill Street, Noe Valley, SF, California,...  37.755725
# ...

# %%
a["longitude"] = a["coordinates"].apply(lambda x: x.longitude)

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State   longitude  \
# 0          8   1      Madeira          CA 94114 -122.429343
# 1         15   2  Bready Shop          CA 94119 -122.425529
# 2         25   3  Super River  California 94114 -122.428601
# 3         10   4   Ben's Shop          CA 94114 -122.431714
# 4         12   5      Sanchez        California -122.429815
# 5         20   6   Richvalley          CA 94114 -122.433220
#
# ...

# %%
a["landl"]=a["longitude"]

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State   longitude  \
# 0          8   1      Madeira          CA 94114 -122.429343
# 1         15   2  Bready Shop          CA 94119 -122.425529
# 2         25   3  Super River  California 94114 -122.428601
# 3         10   4   Ben's Shop          CA 94114 -122.431714
# 4         12   5      Sanchez        California -122.429815
# 5         20   6   Richvalley          CA 94114 -122.433220
#
# ...

# %%
a=a.drop("longitude",1)

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates   latitude       landl
# ...

# %%
a["landl"]=a["latitude"]+","+a["landl"]
a=a.drop("latitude",1)
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\python extracted files\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# d:\python extracted files\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# d:\python extracted files\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# ...

# %%
a["landl"]=a["latitude"]+","+a["landl"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\python extracted files\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# d:\python extracted files\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# d:\python extracted files\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# ...

# %%
import pandas
a["latitude"]=str(a["latitude"])+ "," + str(a["landl"])

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates  \
# 0  (3666, 21st Street, Noe Valley, SF, California...
# ...

# %%
a=a.drop("latitude",1)

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates       landl
# 0  (3666, 21st Street, Noe Valley, SF, California... -122.429343
# ...

# %%
type(a["landl"])
# Out:
# pandas.core.series.Series

# %%
type(",")
# Out:
# str

# %%
type(a["Address"])
# Out:
# pandas.core.series.Series

# %%
a["latitude"]=a["coordinates"].apply(lambda x: x.latitude)

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates       landl   latitude
# ...

# %%
a["latitude"]=a["latitude"]+ a["landl"]

# %%
a
# Out:
#                                       Address           City Country  \
# 0         3666 21st St,San Francisco,CA 94114  San Francisco     USA
# 1       735 Dolores St,San Francisco,CA 94119  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114  San Francisco     USA
# 3         3995 23rd St,San Francisco,CA 94114  San Francisco     USA
# 4    1056 Sanchez St,San Francisco,California  San Francisco     USA
# 5      551 Alvarado St,San Francisco,CA 94114  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates       landl   latitude
# ...

# %%
a["latitude"]=a["latitude"]+ "," +a["Address"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\python extracted files\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1011         try:
# -> 1012             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1013         except TypeError:
#
# d:\python extracted files\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# d:\python extracted files\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      64     with np.errstate(all='ignore'):
# ---> 65         return op(a, b)
#      66
#
# ...

# %%
a["Address"]=a["Address"]+"," +a["City"]

# %%
a
# Out:
#                                              Address           City Country  \
# 0  3666 21st St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 1  735 Dolores St,San Francisco,CA 94119,San Fran...  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114,San...  San Francisco     USA
# 3  3995 23rd St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 4  1056 Sanchez St,San Francisco,California,San F...  San Francisco     USA
# 5  551 Alvarado St,San Francisco,CA 94114,San Fra...  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates       landl   latitude
# ...

# %%
a=a.drop("latitude",1)

# %%
a["latitude"]=a["coordinates"].apply(lambda x: x.latitude)

# %%
a
# Out:
#                                              Address           City Country  \
# 0  3666 21st St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 1  735 Dolores St,San Francisco,CA 94119,San Fran...  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114,San...  San Francisco     USA
# 3  3995 23rd St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 4  1056 Sanchez St,San Francisco,California,San F...  San Francisco     USA
# 5  551 Alvarado St,San Francisco,CA 94114,San Fra...  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates       landl   latitude
# ...

# %%
a['latitude'] = a["latitude"].map(str) + " , " + a["landl"].map(str)

# %%
a
# Out:
#                                              Address           City Country  \
# 0  3666 21st St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 1  735 Dolores St,San Francisco,CA 94119,San Fran...  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114,San...  San Francisco     USA
# 3  3995 23rd St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 4  1056 Sanchez St,San Francisco,California,San F...  San Francisco     USA
# 5  551 Alvarado St,San Francisco,CA 94114,San Fra...  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates       landl  \
# ...

# %%
a['latitude'] = a["latitude"].map(str) + " , " + a["landl"].map(str)

# %%
a
# Out:
#                                              Address           City Country  \
# 0  3666 21st St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 1  735 Dolores St,San Francisco,CA 94119,San Fran...  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114,San...  San Francisco     USA
# 3  3995 23rd St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 4  1056 Sanchez St,San Francisco,California,San F...  San Francisco     USA
# 5  551 Alvarado St,San Francisco,CA 94114,San Fra...  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates       landl  \
# ...

# %%
a=a.drop("latitude",1)

# %%
a["latitude"]=a["coordinates"].apply(lambda x: x.latitude)

# %%
a["latitude"]=a["latitude"].map(str) +","+a["landl"].map(str)

# %%
a=a.drop("landl",1)

# %%
a
# Out:
#                                              Address           City Country  \
# 0  3666 21st St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 1  735 Dolores St,San Francisco,CA 94119,San Fran...  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114,San...  San Francisco     USA
# 3  3995 23rd St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 4  1056 Sanchez St,San Francisco,California,San F...  San Francisco     USA
# 5  551 Alvarado St,San Francisco,CA 94114,San Fra...  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates  \
# ...

# %%
nom_rev=Nominatim(user_agent="first_notebook")

# %%
x_rev=nom_rev.reverse("37.756488877551,-122.429343346939")

# %%
x_rev
# Out:
# Location(801, Sanchez Street, Noe Valley, SF, California, 94114, USA, (37.7561368, -122.4299481, 0.0))

# %%
a["ADD"]=a["latitude"].apply(nom_rev.reverse)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# d:\python extracted files\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# d:\python extracted files\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# d:\python extracted files\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
# ...

# %%
a

# %%
a["ADD"]=a["latitude"].apply(nom_rev.reverse)

# %%
a
# Out:
#                                              Address           City Country  \
# 0  3666 21st St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 1  735 Dolores St,San Francisco,CA 94119,San Fran...  San Francisco     USA
# 2  332 Hill St,San Francisco,California 94114,San...  San Francisco     USA
# 3  3995 23rd St,San Francisco,CA 94114,San Francisco  San Francisco     USA
# 4  1056 Sanchez St,San Francisco,California,San F...  San Francisco     USA
# 5  551 Alvarado St,San Francisco,CA 94114,San Fra...  San Francisco     USA
#
#    Employees  ID         Name             State  \
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114
#
#                                          coordinates  \
# ...
